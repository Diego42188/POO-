# %%
#
import matplotlib.pyplot as plt

class Punto():
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def plot(self):
        plt.scatter(self.x, self.y, color='red', marker='o')
        plt.xlabel('X-axis')
        plt.ylabel('Y-axis')
        plt.title('Gráfica del punto')
        plt.grid(True)
        plt.show()

# %%
punto = Punto(2, 8)#acabamos de construir al punto (2, 8)

# %%
punto.plot()

# %% [markdown]
# aqui ingresamos a la funcion punto para definir las coordenadas de x,y para graficar un punto

# %%
class Palafox(): #creamos una clase
#creamos una definicion
   def __init__(self, altura, grasa corporal):
         self.altura = altura
         self.grasa corporal = grasa corporal

#creamos uns definicion
class ejercicio(Palafox):
  def __init__(self, altura, grasa corporal,trotar)
      super(.__init__(altura,grasa corporal)
      self.trotar=trotar
#creamos una definicion
  def ejercicio(self,trotar):
      if trotar =="trotar":
          print("listo para trotar")
      else
            print("no puedes trotar")
# Out:
#   File "<ipython-input-13-c7604c32c285>", line 3
#     def __init__(self, altura, grasa corporal):
#                                      ^
# SyntaxError: invalid syntax
